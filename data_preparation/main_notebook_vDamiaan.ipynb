# %% [markdown]
# # Assignment 2: Expedia Hotel Recommendations
#
# #### Import relevant packages

# %%
from lightgbm import LGBMRanker
import pandas as pd
import os
import numpy as np
import json
from sklearn.model_selection import GroupShuffleSplit
#import sweetviz as sv
#from imblearn.under_sampling import RandomUnderSampler
import xgboost as xgb
from tqdm import tqdm
import numba
from project_modules.preprocessing import *

pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Load train and test data

# %%
# Add target variable for training set
raw_train = add_target(load_data(train=True))
raw_test = load_data(train=False)

# %%
raw_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4958347 entries, 0 to 4958346
# Data columns (total 55 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   srch_id                      int64
#  1   date_time                    object
#  2   site_id                      object
#  3   visitor_location_country_id  int64
#  4   visitor_hist_starrating      float64
#  5   visitor_hist_adr_usd         float64
#  6   prop_country_id              int64
#  7   prop_id                      int64
#  8   prop_starrating              int64
#  9   prop_review_score            float64
#  10  prop_brand_bool              int64
#  11  prop_location_score1         float64
#  12  prop_location_score2         float64
#  13  prop_log_historical_price    float64
#  14  position                     int64
#  15  price_usd                    float64
#  16  promotion_flag               int64
#  17  srch_destination_id          int64
#  18  srch_length_of_stay          int64
#  19  srch_booking_window          int64
#  20  srch_adults_count            int64
#  21  srch_children_count          int64
#  22  srch_room_count              int64
#  23  srch_saturday_night_bool     int64
#  24  srch_query_affinity_score    float64
#  25  orig_destination_distance    float64
#  26  random_bool                  int64
#  27  comp1_rate                   float64
#  28  comp1_inv                    float64
#  29  comp1_rate_percent_diff      float64
#  30  comp2_rate                   float64
#  31  comp2_inv                    float64
#  32  comp2_rate_percent_diff      float64
#  33  comp3_rate                   float64
#  34  comp3_inv                    float64
#  35  comp3_rate_percent_diff      float64
#  36  comp4_rate                   float64
#  37  comp4_inv                    float64
#  38  comp4_rate_percent_diff      float64
#  39  comp5_rate                   float64
#  40  comp5_inv                    float64
#  41  comp5_rate_percent_diff      float64
#  42  comp6_rate                   float64
#  43  comp6_inv                    float64
#  44  comp6_rate_percent_diff      float64
#  45  comp7_rate                   float64
#  46  comp7_inv                    float64
#  47  comp7_rate_percent_diff      float64
#  48  comp8_rate                   float64
#  49  comp8_inv                    float64
#  50  comp8_rate_percent_diff      float64
#  51  click_bool                   int64
#  52  gross_bookings_usd           float64
#  53  booking_bool                 int64
#  54  target                       int64
# dtypes: float64(34), int64(19), object(2)
# memory usage: 2.0+ GB

# %%
raw_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4959183 entries, 0 to 4959182
# Data columns (total 50 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   srch_id                      int64
#  1   date_time                    object
#  2   site_id                      object
#  3   visitor_location_country_id  int64
#  4   visitor_hist_starrating      float64
#  5   visitor_hist_adr_usd         float64
#  6   prop_country_id              int64
#  7   prop_id                      int64
#  8   prop_starrating              int64
#  9   prop_review_score            float64
#  10  prop_brand_bool              int64
#  11  prop_location_score1         float64
#  12  prop_location_score2         float64
#  13  prop_log_historical_price    float64
#  14  price_usd                    float64
#  15  promotion_flag               int64
#  16  srch_destination_id          int64
#  17  srch_length_of_stay          int64
#  18  srch_booking_window          int64
#  19  srch_adults_count            int64
#  20  srch_children_count          int64
#  21  srch_room_count              int64
#  22  srch_saturday_night_bool     int64
#  23  srch_query_affinity_score    float64
#  24  orig_destination_distance    float64
#  25  random_bool                  int64
#  26  comp1_rate                   float64
#  27  comp1_inv                    float64
#  28  comp1_rate_percent_diff      float64
#  29  comp2_rate                   float64
#  30  comp2_inv                    float64
#  31  comp2_rate_percent_diff      float64
#  32  comp3_rate                   float64
#  33  comp3_inv                    float64
#  34  comp3_rate_percent_diff      float64
#  35  comp4_rate                   float64
#  36  comp4_inv                    float64
#  37  comp4_rate_percent_diff      float64
#  38  comp5_rate                   float64
#  39  comp5_inv                    float64
#  40  comp5_rate_percent_diff      float64
#  41  comp6_rate                   float64
#  42  comp6_inv                    float64
#  43  comp6_rate_percent_diff      float64
#  44  comp7_rate                   float64
#  45  comp7_inv                    float64
#  46  comp7_rate_percent_diff      float64
#  47  comp8_rate                   float64
#  48  comp8_inv                    float64
#  49  comp8_rate_percent_diff      float64
# dtypes: float64(33), int64(15), object(2)
# memory usage: 1.8+ GB

# %% [markdown]
# ### Preprocess data

# %%
df = raw_train

df = ImputeStarrating0(df, ModelperCountry(df)) # Impute starratings that are 0 by a prediction using linear regression
df = add_norm_features(df) # Add 6x prices normalized prices. Each time normalized by other feature. Also adds month feature.

train_idx, val_idx = next(
        GroupShuffleSplit(n_splits=1, test_size=0.1).split(df, groups=df["srch_id"])
)

train, val = df.iloc[train_idx, :], df.iloc[val_idx, :]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\damia\Documents\MASTER\Data Mining Techniques\vu-data-mining-techniques-main\Assignment 2\main_notebook_vDamiaan.ipynb Cell 11' in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/damia/Documents/MASTER/Data%20Mining%20Techniques/vu-data-mining-techniques-main/Assignment%202/main_notebook_vDamiaan.ipynb#ch0000010?line=2'>3</a> df = ImputeStarrating0(df, ModelperCountry(df)) # Impute starratings that are 0 by a prediction using linear regression
#       <a href='vscode-notebook-cell:/c%3A/Users/damia/Documents/MASTER/Data%20Mining%20Techniques/vu-data-mining-techniques-main/Assignment%202/main_notebook_vDamiaan.ipynb#ch0000010?line=3'>4</a> df = add_norm_features(df) # Add 6x prices normalized prices. Each time normalized by other feature. Also adds month feature.
#       <a href='vscode-notebook-cell:/c%3A/Users/damia/Documents/MASTER/Data%20Mining%20Techniques/vu-data-mining-techniques-main/Assignment%202/main_notebook_vDamiaan.ipynb#ch0000010?line=5'>6</a> train_idx, val_idx = next(
# ----> <a href='vscode-notebook-cell:/c%3A/Users/damia/Documents/MASTER/Data%20Mining%20Techniques/vu-data-mining-techniques-main/Assignment%202/main_notebook_vDamiaan.ipynb#ch0000010?line=6'>7</a>         GroupShuffleSplit(n_splits=1, test_size=0.1).split(df, groups=df["srch_id"])
#       <a href='vscode-notebook-cell:/c%3A/Users/damia/Documents/MASTER/Data%20Mining%20Techniques/vu-data-mining-techniques-main/Assignment%202/main_notebook_vDamiaan.ipynb#ch0000010?line=7'>8</a> )
#      <a href='vscode-notebook-cell:/c%3A/Users/damia/Documents/MASTER/Data%20Mining%20Techniques/vu-data-mining-techniques-main/Assignment%202/main_notebook_vDamiaan.ipynb#ch0000010?line=9'>10</a> train, val = df.iloc[train_idx, :], df.iloc[val_idx, :]
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# ### Feature engineering

# %%
#df = featurizing(df)

# %% [markdown]
# ## Fitting models

# %% [markdown]
# #### LightGBM Ranker (LambdaRank)
#
# First define the features and target

# %%
target = "target"

cols = [
    "visitor_hist_starrating",
    "visitor_hist_adr_usd",
    "prop_starrating",
    "prop_review_score",
    "prop_brand_bool",
    "prop_location_score1",
    "prop_location_score2",
    "prop_log_historical_price",
    "price_usd",
    "srch_length_of_stay",
    "srch_booking_window",
    "srch_adults_count",
    "srch_children_count",
    "srch_room_count",
    "srch_query_affinity_score",
    "orig_destination_distance",
    "norm_price_wrt_srch_id",
    "norm_price_wrt_prop_id",
    "norm_price_wrt_srch_destination_id",
    "month",
    "norm_price_wrt_month",
    "norm_price_wrt_srch_booking_window",
    "norm_price_wrt_prop_country_id"
]

id_cols = ["srch_id", "prop_id"]

# %% [markdown]
# Define the group ssizes for the training and validation set, which are needed for the LightGBMRanker

# %%
train_groups = train.groupby("srch_id").size().to_numpy()
val_groups = val.groupby("srch_id").size().to_numpy()

# %%
params = {
    "boosting_type": "gbdt",
    "num_leaves": 31,
    "max_depth": 5,
    "learning_rate": 0.05,
    "n_estimators": 300,
    "objective": "lambdarank",
}

model = LGBMRanker(**params)
model.fit(
    train[cols],
    train[target],
    group=train_groups,
    eval_at=[5],
    eval_set=[(val[cols], val[target])],
    eval_group=[val_groups],
)
# Out:
# [1]	valid_0's ndcg@5: 0.30299
# [2]	valid_0's ndcg@5: 0.32633
# [3]	valid_0's ndcg@5: 0.336864
# [4]	valid_0's ndcg@5: 0.343532
# [5]	valid_0's ndcg@5: 0.349664
# [6]	valid_0's ndcg@5: 0.3509
# [7]	valid_0's ndcg@5: 0.352823
# [8]	valid_0's ndcg@5: 0.35462
# [9]	valid_0's ndcg@5: 0.356616
# [10]	valid_0's ndcg@5: 0.35848
# [11]	valid_0's ndcg@5: 0.358977
# [12]	valid_0's ndcg@5: 0.359742
# [13]	valid_0's ndcg@5: 0.360269
# [14]	valid_0's ndcg@5: 0.360861
# [15]	valid_0's ndcg@5: 0.360477
# [16]	valid_0's ndcg@5: 0.361369
# [17]	valid_0's ndcg@5: 0.361503
# [18]	valid_0's ndcg@5: 0.362487
# [19]	valid_0's ndcg@5: 0.363041
# [20]	valid_0's ndcg@5: 0.363466
# [21]	valid_0's ndcg@5: 0.363107
# [22]	valid_0's ndcg@5: 0.364031
# [23]	valid_0's ndcg@5: 0.363382
# [24]	valid_0's ndcg@5: 0.364335
# [25]	valid_0's ndcg@5: 0.36469
# [26]	valid_0's ndcg@5: 0.365742
# [27]	valid_0's ndcg@5: 0.366318
# [28]	valid_0's ndcg@5: 0.366573
# [29]	valid_0's ndcg@5: 0.366795
# [30]	valid_0's ndcg@5: 0.366888
# [31]	valid_0's ndcg@5: 0.367619
# [32]	valid_0's ndcg@5: 0.366974
# [33]	valid_0's ndcg@5: 0.367005
# [34]	valid_0's ndcg@5: 0.366588
# [35]	valid_0's ndcg@5: 0.366756
# [36]	valid_0's ndcg@5: 0.367052
# [37]	valid_0's ndcg@5: 0.367282
# [38]	valid_0's ndcg@5: 0.367524
# [39]	valid_0's ndcg@5: 0.367539
# [40]	valid_0's ndcg@5: 0.367246
# [244]	valid_0's ndcg@5: 0.379893
# [245]	valid_0's ndcg@5: 0.380029
# [246]	valid_0's ndcg@5: 0.380009
# [247]	valid_0's ndcg@5: 0.380047
# [248]	valid_0's ndcg@5: 0.379997
# [249]	valid_0's ndcg@5: 0.380008
# [250]	valid_0's ndcg@5: 0.380053
# [251]	valid_0's ndcg@5: 0.380219
# [252]	valid_0's ndcg@5: 0.380143
# [253]	valid_0's ndcg@5: 0.379978
# [254]	valid_0's ndcg@5: 0.380117
# [255]	valid_0's ndcg@5: 0.380105
# [256]	valid_0's ndcg@5: 0.380127
# [257]	valid_0's ndcg@5: 0.380165
# [258]	valid_0's ndcg@5: 0.380201
# [259]	valid_0's ndcg@5: 0.379999
# [260]	valid_0's ndcg@5: 0.380069
# [261]	valid_0's ndcg@5: 0.380166
# [262]	valid_0's ndcg@5: 0.380266
# [263]	valid_0's ndcg@5: 0.380211
# [264]	valid_0's ndcg@5: 0.38005
# [265]	valid_0's ndcg@5: 0.380036
# [266]	valid_0's ndcg@5: 0.379948
# [267]	valid_0's ndcg@5: 0.380038
# [268]	valid_0's ndcg@5: 0.380075
# [269]	valid_0's ndcg@5: 0.380055
# [270]	valid_0's ndcg@5: 0.380294
# [271]	valid_0's ndcg@5: 0.380141
# [272]	valid_0's ndcg@5: 0.380072
# [273]	valid_0's ndcg@5: 0.380088
# [274]	valid_0's ndcg@5: 0.380174
# [275]	valid_0's ndcg@5: 0.380115
# [276]	valid_0's ndcg@5: 0.38007
# [277]	valid_0's ndcg@5: 0.380234
# [278]	valid_0's ndcg@5: 0.380097
# [279]	valid_0's ndcg@5: 0.380101
# [280]	valid_0's ndcg@5: 0.380249
# [281]	valid_0's ndcg@5: 0.38022
# [282]	valid_0's ndcg@5: 0.38019
# [283]	valid_0's ndcg@5: 0.380232
# [284]	valid_0's ndcg@5: 0.380286
# [285]	valid_0's ndcg@5: 0.380236
# [286]	valid_0's ndcg@5: 0.380506
# [287]	valid_0's ndcg@5: 0.380537
# [288]	valid_0's ndcg@5: 0.380492
# [289]	valid_0's ndcg@5: 0.380495
# [290]	valid_0's ndcg@5: 0.380652
# [291]	valid_0's ndcg@5: 0.380671
# [292]	valid_0's ndcg@5: 0.380715
# [293]	valid_0's ndcg@5: 0.380989
# [294]	valid_0's ndcg@5: 0.380842
# [295]	valid_0's ndcg@5: 0.380903
# [296]	valid_0's ndcg@5: 0.38096
# [297]	valid_0's ndcg@5: 0.38107
# [298]	valid_0's ndcg@5: 0.381285
# [299]	valid_0's ndcg@5: 0.381254
# [300]	valid_0's ndcg@5: 0.381264
# LGBMRanker(learning_rate=0.05, max_depth=5, n_estimators=300,
#            objective='lambdarank')

# %% [markdown]
# #### Evaluation of LightGBMRanker using NDCG@5

# %%
preds_val = predict_in_batches(model, val, cols, id_cols)

calc_ndcg_submission(preds_val, val)
# Out:
# 25it [00:23,  1.08it/s]
# 0.3820363595976368

# %%
preds_test = predict_in_batches(model, raw_test, cols, id_cols)

# Save predictions for test set to csv
preds_test.to_csv("predictions_try1.csv", index=False)
# Out:
# 248it [01:04,  3.84it/s]
