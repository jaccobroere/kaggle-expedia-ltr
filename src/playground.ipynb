# %%
import logging
import configparser
import os
from dask import dataframe as dd
import datetime as dt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import lightgbm as lgb

# Data cleaning
import janitor

# %%
# Read config file
config = configparser.ConfigParser()
config.read("config.ini")

# Read parameters from config file
ROOT_DIR = config["FILES"]["ROOT_DIR"]
TRAIN = config["DATA"]["SUBSET_TRAINING_DATA"]
TEST = config["DATA"]["SUBSET_TEST_DATA"]

# Change working directory
os.chdir(ROOT_DIR)

# %%
raw = pd.read_parquet(TRAIN)

df = raw.copy()

# %%
df = df.clean_names()

# Change index name
df = df.rename_axis("id")

raw.head()
# Out:
#                      srch_id            date_time  site_id  \
# __null_dask_index__
# 993                       78  2012-12-21 05:30:35        5
# 994                       78  2012-12-21 05:30:35        5
# 995                       78  2012-12-21 05:30:35        5
# 996                       78  2012-12-21 05:30:35        5
# 997                       78  2012-12-21 05:30:35        5
#
#                      visitor_location_country_id  visitor_hist_starrating  \
# __null_dask_index__
# 993                                          205                      NaN
# 994                                          205                      NaN
# 995                                          205                      NaN
# 996                                          205                      NaN
# 997                                          205                      NaN
#
#                      visitor_hist_adr_usd  prop_country_id  prop_id  \
# __null_dask_index__
# 993                                   NaN               15     9246
# 994                                   NaN               15    10223
# 995                                   NaN               15    16549
# 996                                   NaN               15    31638
# 997                                   NaN               15    35509
#
#                      prop_starrating  prop_review_score  ...  \
# __null_dask_index__                                      ...
# 993                                5                5.0  ...
# 994                                4                4.5  ...
# 995                                4                3.0  ...
# 996                                5                4.5  ...
# 997                                5                4.5  ...
#
#                      comp6_rate_percent_diff  comp7_rate  comp7_inv  \
# __null_dask_index__
# 993                                      NaN         NaN        NaN
# 994                                      NaN         NaN        NaN
# 995                                      NaN         NaN        NaN
# 996                                      NaN         0.0        0.0
# 997                                      NaN         NaN        NaN
#
#                      comp7_rate_percent_diff  comp8_rate  comp8_inv  \
# __null_dask_index__
# 993                                      NaN         NaN        NaN
# 994                                      NaN         NaN        NaN
# 995                                      NaN         NaN        NaN
# 996                                      NaN         NaN        NaN
# 997                                      NaN         NaN        NaN
#
#                      comp8_rate_percent_diff  click_bool  gross_bookings_usd  \
# __null_dask_index__
# 993                                      NaN           0                 NaN
# 994                                      NaN           0                 NaN
# 995                                      NaN           0                 NaN
# 996                                      NaN           0                 NaN
# 997                                      NaN           0                 NaN
#
#                      booking_bool
# __null_dask_index__
# 993                             0
# 994                             0
# 995                             0
# 996                             0
# 997                             0
#
# [5 rows x 54 columns]
